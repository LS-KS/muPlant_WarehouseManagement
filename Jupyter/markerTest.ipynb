# %% [markdown]
# # Performance testing on arUco marker from different angles

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Images

# %%
img = cv2.imread("arUco MacbookTest.png",cv2.IMREAD_COLOR)
img2 = cv2.imread("arUcoTest.png", cv2.IMREAD_COLOR)
arucos = cv2.aruco.getPredefinedDictionary(cv2.aruco.DICT_6X6_250)

(corners, ids, rejected) = cv2.aruco.detectMarkers(img2, arucos,)
print(corners)
print(ids)
print(rejected)
# Out:
# (array([[[1715., 1522.],
#         [1769., 1520.],
#         [1770., 1575.],
#         [1716., 1576.]]], dtype=float32), array([[[1862., 1520.],
#         [1916., 1518.],
#         [1917., 1575.],
#         [1863., 1575.]]], dtype=float32), array([[[1789., 1520.],
#         [1842., 1519.],
#         [1844., 1575.],
#         [1790., 1576.]]], dtype=float32), array([[[2010., 1518.],
#         [2066., 1517.],
#         [2066., 1573.],
#         [2011., 1574.]]], dtype=float32), array([[[1937., 1518.],
#         [1992., 1519.],
#         [1991., 1574.],
#         [1936., 1574.]]], dtype=float32))
# [[5]
#  [7]
#  [6]
#  [9]
#  [8]]
# (array([[[ 888., 3201.],
#         [ 896., 3225.],
#         [ 895., 3270.],
#         [ 888., 3261.]]], dtype=float32), array([[[2086., 1498.],
#         [2086., 1758.],
#         [1696., 1759.],
#         [1696., 1500.]]], dtype=float32))

# %%
if ids is not None:
    img2 = cv2.aruco.drawDetectedMarkers(img2, corners, ids)

# %%
    # Display the image with markers
    plt.imshow(img2)
